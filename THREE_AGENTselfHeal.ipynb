# %% [markdown]
# <a href="https://colab.research.google.com/github/treborskrub/Three_Agent_Process_Engine_v0_4_1/blob/main/THREE_AGENTselfHeal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# THREE-AGENT PROCESS DESIGN ENGINE v0.5
# AUDIT -> RESOLVE -> PRUNE / RESTORE / PROTECT
# =============================================================================
# Purpose:
# - Build on v0.4.1 Safe Path-Level Adaptive Pruning.
# - Make the decision loop explicit:
#
#       MEASURE -> AUDIT -> RESOLVE -> APPLY BOUNDED CHANGE -> MEASURE
#
# - Audit supplies evidence.
# - Resolve supplies judgment.
# - Prune / restore / protect supplies bounded action.
#
# This is a deterministic abstract process-control model.
# It is not a physical, semantic-reasoning, or quantum-hardware simulation.
# =============================================================================

from dataclasses import dataclass
from copy import deepcopy

EPSILON = 1e-9

# -----------------------------------------------------------------------------
# CONTROL PANEL
# -----------------------------------------------------------------------------
SETSTATE_TASK_SUM = 100.0
MAX_CYCLES = 12

BALANCE_FLOOR = 0.90
WATCH_FLOOR = 0.80
CRITICAL_FLOOR = 0.67
EFFICIENCY_CEILING = 1.05

CRITICAL_EXIT_RATIO = 0.80
MAX_CRITICAL_ENTRIES = 3
WASTEFUL_CONFIRMATION_CYCLES = 2

# -----------------------------------------------------------------------------
# PATH MODEL
# -----------------------------------------------------------------------------
@dataclass
class TaskPath:
    name: str
    contribution: float
    cost: float
    reliability: float
    priority: str
    protected: bool = False
    active: bool = True
    status: str = "ACTIVE"
    monitored_cycles: int = 0

    def value_score(self):
        return (self.contribution * self.reliability) / max(self.cost, EPSILON)

# -----------------------------------------------------------------------------
# BASE MEASUREMENTS
# -----------------------------------------------------------------------------
def active_task_sum(paths):
    return sum(path.contribution for path in paths if path.active)

def active_cost(paths):
    return sum(path.cost for path in paths if path.active)

def priority_rank(priority):
    return {
        "CORE": 3,
        "HIGH": 2,
        "NORMAL": 1,
        "LOW": 0,
    }.get(priority, 0)

def classify_state(ratio):
    if ratio < CRITICAL_FLOOR:
        return "CRITICAL"
    if ratio < WATCH_FLOOR:
        return "SHORTFALL_1_3"
    if ratio < BALANCE_FLOOR:
        return "WATCH"
    if ratio >= EFFICIENCY_CEILING:
        return "EFFICIENCY"
    return "BALANCE"

def direction_from_target(previous_sum, current_sum, setstate):
    previous_distance = abs(1.0 - previous_sum / max(setstate, EPSILON))
    current_distance = abs(1.0 - current_sum / max(setstate, EPSILON))

    if current_distance < previous_distance:
        return "CLOSER"
    if current_distance > previous_distance:
        return "FARTHER"
    return "NO_CHANGE"

def efficiency_status(previous_sum, current_sum, previous_cost, setstate):
    previous_distance = abs(1.0 - previous_sum / max(setstate, EPSILON))
    current_distance = abs(1.0 - current_sum / max(setstate, EPSILON))
    improvement = previous_distance - current_distance
    efficiency = improvement / max(previous_cost, EPSILON)

    if efficiency > 0.0001:
        status = "PRODUCTIVE"
    elif efficiency < -0.0001:
        status = "WASTEFUL"
    else:
        status = "STALLED"

    return status, improvement, efficiency

# -----------------------------------------------------------------------------
# AGENT 1: AUDIT
# Collects measurable evidence. It does not choose an action.
# -----------------------------------------------------------------------------
def audit_agent(paths, setstate, previous_sum, previous_cost,
                critical_entries, wasteful_cycles):
    current_sum = active_task_sum(paths)
    current_cost = active_cost(paths)
    ratio = current_sum / max(setstate, EPSILON)

    direction = direction_from_target(previous_sum, current_sum, setstate)
    efficiency, improvement, efficiency_value = efficiency_status(
        previous_sum, current_sum, previous_cost, setstate
    )

    state = classify_state(ratio)

    active_paths = [path for path in paths if path.active]
    inactive_paths = [path for path in paths if not path.active]

    optional_active = [
        path for path in active_paths
        if not path.protected and path.priority != "CORE"
    ]

    optional_active.sort(
        key=lambda path: (
            priority_rank(path.priority),
            path.value_score(),
            path.reliability,
        )
    )

    restore_candidates = [
        path for path in inactive_paths
        if not path.protected and path.priority != "CORE"
    ]

    restore_candidates.sort(
        key=lambda path: (
            -priority_rank(path.priority),
            -path.value_score(),
            -path.reliability,
        )
    )

    prune_candidate = optional_active[0] if optional_active else None
    restore_candidate = restore_candidates[0] if restore_candidates else None

    if prune_candidate:
        projected_sum_after_prune = current_sum - prune_candidate.contribution
        projected_ratio_after_prune = (
            projected_sum_after_prune / max(setstate, EPSILON)
        )
    else:
        projected_sum_after_prune = current_sum
        projected_ratio_after_prune = ratio

    return {
        "current_sum": current_sum,
        "current_cost": current_cost,
        "ratio": ratio,
        "distance": abs(1.0 - ratio),
        "state": state,
        "direction": direction,
        "efficiency": efficiency,
        "improvement": improvement,
        "efficiency_value": efficiency_value,
        "critical_entries": critical_entries,
        "wasteful_cycles": wasteful_cycles,
        "active_count": len(active_paths),
        "inactive_count": len(inactive_paths),
        "prune_candidate": prune_candidate,
        "restore_candidate": restore_candidate,
        "projected_sum_after_prune": projected_sum_after_prune,
        "projected_ratio_after_prune": projected_ratio_after_prune,
    }

# -----------------------------------------------------------------------------
# AGENT 2: RESOLVE
# Converts audit evidence into a decision.
# It does not change any path by itself.
# -----------------------------------------------------------------------------
def resolve_agent(audit, critical_lockout):
    ratio = audit["ratio"]
    state = audit["state"]

    if audit["critical_entries"] >= MAX_CRITICAL_ENTRIES:
        return {
            "decision_state": "RESET_REQUIRED",
            "action": "RESEED_PROTECTED_CORE",
            "reason": "Critical-entry limit reached; only protected paths remain.",
            "critical_lockout": True,
        }

    if critical_lockout and ratio < CRITICAL_EXIT_RATIO:
        return {
            "decision_state": "CRITICAL_LOCKOUT",
            "action": "PROTECT_AND_REDUCE",
            "reason": (
                f"Protected recovery remains active until ratio reaches "
                f"{CRITICAL_EXIT_RATIO:.2f}."
            ),
            "critical_lockout": True,
        }

    if state == "CRITICAL":
        return {
            "decision_state": "CRITICAL",
            "action": "PROTECT_AND_REDUCE",
            "reason": "Task is below the critical floor; protect core capacity.",
            "critical_lockout": True,
        }

    if state == "SHORTFALL_1_3":
        return {
            "decision_state": "SHORTFALL_1_3",
            "action": "AUDIT_FOR_RECOVERY",
            "reason": "Shortfall requires observation before removal of capacity.",
            "critical_lockout": False,
        }

    if state == "WATCH":
        if audit["direction"] == "CLOSER" and audit["restore_candidate"]:
            return {
                "decision_state": "WATCH",
                "action": "RESTORE_ONE_PATH",
                "reason": "Recovery is improving; restore one worthwhile path.",
                "critical_lockout": False,
            }

        return {
            "decision_state": "WATCH",
            "action": "MONITOR_CANDIDATE",
            "reason": "Watch state lacks confirmed recovery.",
            "critical_lockout": False,
        }

    if state == "EFFICIENCY":
        return {
            "decision_state": "EFFICIENCY",
            "action": "SAFE_PRUNE_OR_MONITOR",
            "reason": "Excess activity requires a bounded efficiency correction.",
            "critical_lockout": False,
        }

    if audit["efficiency"] == "WASTEFUL":
        if audit["wasteful_cycles"] >= WASTEFUL_CONFIRMATION_CYCLES:
            return {
                "decision_state": "BALANCE",
                "action": "SAFE_PRUNE_OR_MONITOR",
                "reason": "Repeated wasteful movement supports candidate review.",
                "critical_lockout": False,
            }

        return {
            "decision_state": "BALANCE",
            "action": "HOLD_AND_AUDIT",
            "reason": "One wasteful cycle is insufficient evidence for pruning.",
            "critical_lockout": False,
        }

    return {
        "decision_state": "BALANCE",
        "action": "RETAIN_AND_AUDIT",
        "reason": "System is balanced without confirmed need for intervention.",
        "critical_lockout": False,
    }

# -----------------------------------------------------------------------------
# AGENT 3: BOUNDED ACTION
# Executes one safe action; never changes more than one optional path per cycle.
# -----------------------------------------------------------------------------
def prune_agent(paths, audit, decision, setstate):
    action = decision["action"]
    changed_paths = []
    result = "NO_PATH_CHANGE"

    if action == "SAFE_PRUNE_OR_MONITOR":
        candidate = audit["prune_candidate"]

        if candidate is None:
            result = "NO_OPTIONAL_PATH_AVAILABLE"

        elif candidate.monitored_cycles < 1:
            candidate.monitored_cycles += 1
            candidate.status = "MONITORED"
            changed_paths.append(candidate.name)
            result = "MONITORED_NOT_PRUNED"

        elif audit["projected_ratio_after_prune"] < BALANCE_FLOOR:
            candidate.monitored_cycles += 1
            candidate.status = "PRUNE_BLOCKED_BY_SAFETY_GUARD"
            changed_paths.append(candidate.name)
            result = "PRUNE_BLOCKED_BY_SAFETY_GUARD"

        else:
            candidate.active = False
            candidate.status = "PRUNED"
            candidate.monitored_cycles = 0
            changed_paths.append(candidate.name)
            result = "PRUNED_SAFELY"

    elif action == "RESTORE_ONE_PATH":
        candidate = audit["restore_candidate"]

        if candidate is None:
            result = "NO_PATH_AVAILABLE_TO_RESTORE"
        else:
            candidate.active = True
            candidate.status = "RESTORED"
            candidate.monitored_cycles = 0
            changed_paths.append(candidate.name)
            result = "PATH_RESTORED"

    elif action == "PROTECT_AND_REDUCE":
        for path in paths:
            if path.protected or path.priority == "CORE":
                if not path.active:
                    path.active = True
                    changed_paths.append(path.name)
                path.status = "CORE_PROTECTED"

        candidate = audit["prune_candidate"]
        if candidate and candidate.active:
            candidate.active = False
            candidate.status = "PROTECTIVE_PRUNE"
            candidate.monitored_cycles = 0
            changed_paths.append(candidate.name)

        result = "CORE_PROTECTED_AND_ONE_OPTIONAL_REDUCED"

    elif action == "RESEED_PROTECTED_CORE":
        for path in paths:
            if path.protected or path.priority == "CORE":
                if not path.active:
                    changed_paths.append(path.name)
                path.active = True
                path.status = "SOURCE_RESEEDED"
            else:
                if path.active:
                    changed_paths.append(path.name)
                path.active = False
                path.status = "RESET_PRUNED"
                path.monitored_cycles = 0

        result = "RESEEDED_FROM_PROTECTED_CORE"

    elif action == "MONITOR_CANDIDATE":
        candidate = audit["prune_candidate"]
        if candidate:
            candidate.monitored_cycles += 1
            candidate.status = "MONITORED"
            changed_paths.append(candidate.name)
            result = "CANDIDATE_MONITORED"
        else:
            result = "NO_OPTIONAL_PATH_TO_MONITOR"

    return {
        "result": result,
        "changed_paths": changed_paths,
    }

# -----------------------------------------------------------------------------
# ENVIRONMENT
# Controlled and deterministic path updates.
# Later, a geometry layer can replace this with connected-node effects.
# -----------------------------------------------------------------------------
def update_active_path_contributions(paths, cycle):
    for path in paths:
        if not path.active:
            continue

        if path.protected:
            change = 0.5
        elif path.reliability >= 0.85:
            change = 1.0
        elif path.reliability >= 0.60:
            change = 0.2
        else:
            change = -1.5

        if cycle % 4 == 0 and not path.protected:
            change -= 0.5

        path.contribution = max(0.0, path.contribution + change)

# -----------------------------------------------------------------------------
# DISPLAY
# -----------------------------------------------------------------------------
def candidate_name(candidate):
    return candidate.name if candidate else "None"

def print_paths(paths):
    print(
        f"{'Path':<16}"
        f"{'Contribution':<15}"
        f"{'Cost':<9}"
        f"{'Reliability':<12}"
        f"{'Priority':<10}"
        f"{'Protected':<11}"
        f"{'Active':<8}"
        f"{'Status'}"
    )
    print("-" * 110)

    for path in paths:
        print(
            f"{path.name:<16}"
            f"{path.contribution:<15.2f}"
            f"{path.cost:<9.2f}"
            f"{path.reliability:<12.2f}"
            f"{path.priority:<10}"
            f"{str(path.protected):<11}"
            f"{str(path.active):<8}"
            f"{path.status}"
        )

# -----------------------------------------------------------------------------
# INITIAL PATHS
# -----------------------------------------------------------------------------
INITIAL_PATHS = [
    TaskPath("Core_Signal",   32.0, 2.0, 0.98, "CORE",   True),
    TaskPath("Core_Memory",   24.0, 2.5, 0.92, "CORE",   True),
    TaskPath("Reliable_Path", 18.0, 2.0, 0.88, "HIGH",   False),
    TaskPath("Medium_Path",   14.0, 4.0, 0.62, "NORMAL", False),
    TaskPath("Weak_Path",     10.0, 6.0, 0.32, "LOW",    False),
]

# -----------------------------------------------------------------------------
# MAIN RUN
# -----------------------------------------------------------------------------
paths = deepcopy(INITIAL_PATHS)

previous_sum = active_task_sum(paths)
previous_cost = max(active_cost(paths), 1.0)

critical_lockout = False
critical_entries = 0
wasteful_cycles = 0
history = []

print("\n" + "=" * 110)
print("THREE-AGENT PROCESS DESIGN ENGINE v0.5")
print("MEASURE -> AUDIT -> RESOLVE -> BOUNDED ACTION -> MEASURE")
print("=" * 110)
print(f"SetState: {SETSTATE_TASK_SUM:.2f}")
print(f"Balance safety floor: {BALANCE_FLOOR:.2f}")
print(f"Initial active task sum: {previous_sum:.2f}")
print("\nINITIAL PATH CONFIGURATION")
print_paths(paths)

for cycle in range(1, MAX_CYCLES + 1):
    # 1. AUDIT: measure and collect evidence
    audit = audit_agent(
        paths=paths,
        setstate=SETSTATE_TASK_SUM,
        previous_sum=previous_sum,
        previous_cost=previous_cost,
        critical_entries=critical_entries,
        wasteful_cycles=wasteful_cycles,
    )

    # Update counters after the audit measurement.
    if audit["efficiency"] == "WASTEFUL":
        wasteful_cycles += 1
    else:
        wasteful_cycles = 0

    if audit["state"] == "CRITICAL":
        critical_entries += 1

    # Refresh audit with the current counters for resolution.
    audit["wasteful_cycles"] = wasteful_cycles
    audit["critical_entries"] = critical_entries

    # 2. RESOLVE: choose one bounded next action
    decision = resolve_agent(audit, critical_lockout)
    critical_lockout = decision["critical_lockout"]

    # 3. ACT: apply the decision safely
    action_result = prune_agent(
        paths=paths,
        audit=audit,
        decision=decision,
        setstate=SETSTATE_TASK_SUM,
    )

    # 4. ENVIRONMENT: calculate next-cycle path contributions
    update_active_path_contributions(paths, cycle)
    next_sum = active_task_sum(paths)

    history.append({
        "cycle": cycle,
        "current_sum": audit["current_sum"],
        "ratio": audit["ratio"],
        "direction": audit["direction"],
        "efficiency": audit["efficiency"],
        "state": audit["state"],
        "decision": decision["decision_state"],
        "action": decision["action"],
        "candidate": candidate_name(audit["prune_candidate"]),
        "projected_ratio": audit["projected_ratio_after_prune"],
        "result": action_result["result"],
        "next_sum": next_sum,
    })

    print("\n" + "-" * 110)
    print(f"CYCLE {cycle}")
    print("-" * 110)
    print(
        f"MEASURE  | Sum: {audit['current_sum']:.2f} | "
        f"Ratio: {audit['ratio']:.3f} | "
        f"State: {audit['state']} | "
        f"Direction: {audit['direction']} | "
        f"Efficiency: {audit['efficiency']}"
    )
    print(
        f"AUDIT    | Wasteful cycles: {wasteful_cycles} | "
        f"Critical entries: {critical_entries} | "
        f"Prune candidate: {candidate_name(audit['prune_candidate'])} | "
        f"Projected ratio after candidate prune: "
        f"{audit['projected_ratio_after_prune']:.3f}"
    )
    print(
        f"RESOLVE  | Decision state: {decision['decision_state']} | "
        f"Action: {decision['action']}"
    )
    print(f"REASON   | {decision['reason']}")
    print(f"ACTION   | {action_result['result']}")

    if action_result["changed_paths"]:
        print("CHANGED  | " + ", ".join(action_result["changed_paths"]))
    else:
        print("CHANGED  | None")

    print(f"NEXT     | Task sum after path update: {next_sum:.2f}")

    previous_sum = audit["current_sum"]
    previous_cost = max(audit["current_cost"], 1.0)

# -----------------------------------------------------------------------------
# FINAL REPORT
# -----------------------------------------------------------------------------
final_sum = active_task_sum(paths)
final_ratio = final_sum / SETSTATE_TASK_SUM
final_distance = abs(1.0 - final_ratio)
final_state = classify_state(final_ratio)

print("\n" + "=" * 110)
print("FINAL PATH CONFIGURATION")
print("=" * 110)
print_paths(paths)

print("\n" + "=" * 110)
print("FINAL AUDIT / RESOLVE HISTORY")
print("=" * 110)
print(
    f"{'Cycle':<7}"
    f"{'Current':<11}"
    f"{'Ratio':<9}"
    f"{'State':<17}"
    f"{'Efficiency':<13}"
    f"{'Candidate':<16}"
    f"{'Action':<27}"
    f"{'Result':<33}"
    f"{'Next'}"
)
print("-" * 110)

for row in history:
    print(
        f"{row['cycle']:<7}"
        f"{row['current_sum']:<11.2f}"
        f"{row['ratio']:<9.3f}"
        f"{row['state']:<17}"
        f"{row['efficiency']:<13}"
        f"{row['candidate']:<16}"
        f"{row['action']:<27}"
        f"{row['result']:<33}"
        f"{row['next_sum']:<10.2f}"
    )

print("=" * 110)
print(f"Final active task sum: {final_sum:.2f}")
print(f"Final ratio r: {final_ratio:.3f}")
print(f"Distance from SetState: {final_distance:.3f}")
print(f"Final state: {final_state}")

if BALANCE_FLOOR <= final_ratio < EFFICIENCY_CEILING:
    verdict = "BALANCE RANGE REACHED"
elif WATCH_FLOOR <= final_ratio < BALANCE_FLOOR:
    verdict = "WATCH / PARTIAL RECOVERY"
elif final_ratio < CRITICAL_FLOOR:
    verdict = "CRITICAL SHORTFALL REMAINS"
elif final_ratio < WATCH_FLOOR:
    verdict = "ONE-THIRD SHORTFALL REMAINS"
else:
    verdict = "EFFICIENCY CORRECTION STILL NEEDED"

print(f"FINAL VERDICT: {verdict}")
print("=" * 110)
print("v0.5 baseline: Audit provides evidence; resolve selects action;")
print("bounded action changes at most one optional path per cycle.")
print("=" * 110)
# Out:
# ==============================================================================================================
# THREE-AGENT PROCESS DESIGN ENGINE v0.5
# MEASURE -> AUDIT -> RESOLVE -> BOUNDED ACTION -> MEASURE
# ==============================================================================================================
# SetState: 100.00
# Balance safety floor: 0.90
# Initial active task sum: 98.00
#
# INITIAL PATH CONFIGURATION
# Path            Contribution   Cost     Reliability Priority  Protected  Active  Status
# --------------------------------------------------------------------------------------------------------------
# Core_Signal     32.00          2.00     0.98        CORE      True       True    ACTIVE
# Core_Memory     24.00          2.50     0.92        CORE      True       True    ACTIVE
# Reliable_Path   18.00          2.00     0.88        HIGH      False      True    ACTIVE
# Medium_Path     14.00          4.00     0.62        NORMAL    False      True    ACTIVE
# Weak_Path       10.00          6.00     0.32        LOW       False      True    ACTIVE
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 1
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 98.00 | Ratio: 0.980 | State: BALANCE | Direction: NO_CHANGE | Efficiency: STALLED
# AUDIT    | Wasteful cycles: 0 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 0.880
# RESOLVE  | Decision state: BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 98.70
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 2
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 98.70 | Ratio: 0.987 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Wasteful cycles: 0 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 0.902
# RESOLVE  | Decision state: BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 99.40
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 3
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 99.40 | Ratio: 0.994 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Wasteful cycles: 0 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 0.924
# RESOLVE  | Decision state: BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 100.10
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 4
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 100.10 | Ratio: 1.001 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Wasteful cycles: 0 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 0.946
# RESOLVE  | Decision state: BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 99.30
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 5
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 99.30 | Ratio: 0.993 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Wasteful cycles: 1 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 0.958
# RESOLVE  | Decision state: BALANCE | Action: HOLD_AND_AUDIT
# REASON   | One wasteful cycle is insufficient evidence for pruning.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 100.00
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 6
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 100.00 | Ratio: 1.000 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Wasteful cycles: 0 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 0.980
# RESOLVE  | Decision state: BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 100.70
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 7
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 100.70 | Ratio: 1.007 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Wasteful cycles: 1 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 1.002
# RESOLVE  | Decision state: BALANCE | Action: HOLD_AND_AUDIT
# REASON   | One wasteful cycle is insufficient evidence for pruning.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 102.40
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 8
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 102.40 | Ratio: 1.024 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Wasteful cycles: 2 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 1.024
# RESOLVE  | Decision state: BALANCE | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Repeated wasteful movement supports candidate review.
# ACTION   | MONITORED_NOT_PRUNED
# CHANGED  | Weak_Path
# NEXT     | Task sum after path update: 103.60
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 9
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 103.60 | Ratio: 1.036 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Wasteful cycles: 3 | Critical entries: 0 | Prune candidate: Weak_Path | Projected ratio after candidate prune: 1.036
# RESOLVE  | Decision state: BALANCE | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Repeated wasteful movement supports candidate review.
# ACTION   | PRUNED_SAFELY
# CHANGED  | Weak_Path
# NEXT     | Task sum after path update: 105.80
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 10
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 105.80 | Ratio: 1.058 | State: EFFICIENCY | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Wasteful cycles: 4 | Critical entries: 0 | Prune candidate: Medium_Path | Projected ratio after candidate prune: 0.910
# RESOLVE  | Decision state: EFFICIENCY | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Excess activity requires a bounded efficiency correction.
# ACTION   | MONITORED_NOT_PRUNED
# CHANGED  | Medium_Path
# NEXT     | Task sum after path update: 108.00
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 11
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 108.00 | Ratio: 1.080 | State: EFFICIENCY | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Wasteful cycles: 5 | Critical entries: 0 | Prune candidate: Medium_Path | Projected ratio after candidate prune: 0.930
# RESOLVE  | Decision state: EFFICIENCY | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Excess activity requires a bounded efficiency correction.
# ACTION   | PRUNED_SAFELY
# CHANGED  | Medium_Path
# NEXT     | Task sum after path update: 95.00
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 12
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 95.00 | Ratio: 0.950 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Wasteful cycles: 0 | Critical entries: 0 | Prune candidate: Reliable_Path | Projected ratio after candidate prune: 0.670
# RESOLVE  | Decision state: BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum after path update: 96.50
#
# ==============================================================================================================
# FINAL PATH CONFIGURATION
# ==============================================================================================================
# Path            Contribution   Cost     Reliability Priority  Protected  Active  Status
# --------------------------------------------------------------------------------------------------------------
# Core_Signal     38.00          2.00     0.98        CORE      True       True    ACTIVE
# Core_Memory     30.00          2.50     0.92        CORE      True       True    ACTIVE
# Reliable_Path   28.50          2.00     0.88        HIGH      False      True    ACTIVE
# Medium_Path     15.00          4.00     0.62        NORMAL    False      False   PRUNED
# Weak_Path       0.00           6.00     0.32        LOW       False      False   PRUNED
#
# ==============================================================================================================
# FINAL AUDIT / RESOLVE HISTORY
# ==============================================================================================================
# Cycle  Current    Ratio    State            Efficiency   Candidate       Action                     Result                           Next
# --------------------------------------------------------------------------------------------------------------
# 1      98.00      0.980    BALANCE          STALLED      Weak_Path       RETAIN_AND_AUDIT           NO_PATH_CHANGE                   98.70
# 2      98.70      0.987    BALANCE          PRODUCTIVE   Weak_Path       RETAIN_AND_AUDIT           NO_PATH_CHANGE                   99.40
# 3      99.40      0.994    BALANCE          PRODUCTIVE   Weak_Path       RETAIN_AND_AUDIT           NO_PATH_CHANGE                   100.10
# 4      100.10     1.001    BALANCE          PRODUCTIVE   Weak_Path       RETAIN_AND_AUDIT           NO_PATH_CHANGE                   99.30
# 5      99.30      0.993    BALANCE          WASTEFUL     Weak_Path       HOLD_AND_AUDIT             NO_PATH_CHANGE                   100.00
# 6      100.00     1.000    BALANCE          PRODUCTIVE   Weak_Path       RETAIN_AND_AUDIT           NO_PATH_CHANGE                   100.70
# 7      100.70     1.007    BALANCE          WASTEFUL     Weak_Path       HOLD_AND_AUDIT             NO_PATH_CHANGE                   102.40
# 8      102.40     1.024    BALANCE          WASTEFUL     Weak_Path       SAFE_PRUNE_OR_MONITOR      MONITORED_NOT_PRUNED             103.60
# 9      103.60     1.036    BALANCE          WASTEFUL     Weak_Path       SAFE_PRUNE_OR_MONITOR      PRUNED_SAFELY                    105.80
# 10     105.80     1.058    EFFICIENCY       WASTEFUL     Medium_Path     SAFE_PRUNE_OR_MONITOR      MONITORED_NOT_PRUNED             108.00
# 11     108.00     1.080    EFFICIENCY       WASTEFUL     Medium_Path     SAFE_PRUNE_OR_MONITOR      PRUNED_SAFELY                    95.00
# 12     95.00      0.950    BALANCE          PRODUCTIVE   Reliable_Path   RETAIN_AND_AUDIT           NO_PATH_CHANGE                   96.50
# ==============================================================================================================
# Final active task sum: 96.50
# Final ratio r: 0.965
# Distance from SetState: 0.035
# Final state: BALANCE
# FINAL VERDICT: BALANCE RANGE REACHED
# ==============================================================================================================
# v0.5 baseline: Audit provides evidence; resolve selects action;
# bounded action changes at most one optional path per cycle.
# ==============================================================================================================

# %%
three_agent_process_design_engine_v0_5.py

# %%
from dataclasses import dataclass
from copy import deepcopy

EPSILON = 1e-9

# -----------------------------------------------------------------------------
# CONTROL PANEL
# -----------------------------------------------------------------------------
SETSTATE_TASK_SUM = 100.0
MAX_CYCLES = 14

BALANCE_FLOOR = 0.90
WATCH_FLOOR = 0.80
CRITICAL_FLOOR = 0.67
EFFICIENCY_CEILING = 1.05

CRITICAL_EXIT_RATIO = 0.80
MAX_CRITICAL_ENTRIES = 3
WASTEFUL_CONFIRMATION_CYCLES = 2

# Controlled failure injection:
# At this cycle, the named active path loses its contribution and is disabled.
FAILURE_CYCLE = 3
FAILURE_PATH_NAME = "Reliable_Path"

# The self-healing evaluator checks recovery across this many later cycles.
HEALING_WINDOW = 2

# -----------------------------------------------------------------------------
# PATH MODEL
# -----------------------------------------------------------------------------
@dataclass
class TaskPath:
    name: str
    contribution: float
    cost: float
    reliability: float
    priority: str
    protected: bool = False
    active: bool = True
    status: str = "ACTIVE"
    monitored_cycles: int = 0

    def value_score(self):
        return (self.contribution * self.reliability) / max(self.cost, EPSILON)

# -----------------------------------------------------------------------------
# MEASUREMENT HELPERS
# -----------------------------------------------------------------------------
def active_task_sum(paths):
    return sum(path.contribution for path in paths if path.active)

def active_cost(paths):
    return sum(path.cost for path in paths if path.active)

def priority_rank(priority):
    return {"CORE": 3, "HIGH": 2, "NORMAL": 1, "LOW": 0}.get(priority, 0)

def classify_state(ratio):
    if ratio < CRITICAL_FLOOR:
        return "CRITICAL"
    if ratio < WATCH_FLOOR:
        return "SHORTFALL_1_3"
    if ratio < BALANCE_FLOOR:
        return "WATCH"
    if ratio >= EFFICIENCY_CEILING:
        return "EFFICIENCY"
    return "BALANCE"

def direction_from_target(previous_sum, current_sum, setstate):
    before = abs(1.0 - previous_sum / max(setstate, EPSILON))
    now = abs(1.0 - current_sum / max(setstate, EPSILON))

    if now < before:
        return "CLOSER"
    if now > before:
        return "FARTHER"
    return "NO_CHANGE"

def efficiency_status(previous_sum, current_sum, previous_cost, setstate):
    before = abs(1.0 - previous_sum / max(setstate, EPSILON))
    now = abs(1.0 - current_sum / max(setstate, EPSILON))
    improvement = before - now
    value = improvement / max(previous_cost, EPSILON)

    if value > 0.0001:
        status = "PRODUCTIVE"
    elif value < -0.0001:
        status = "WASTEFUL"
    else:
        status = "STALLED"

    return status, improvement, value

# -----------------------------------------------------------------------------
# OPERATIONAL AUDIT AGENT
# Collects evidence used by the resolver.
# -----------------------------------------------------------------------------
def audit_agent(paths, setstate, previous_sum, previous_cost,
                critical_entries, wasteful_cycles):
    current_sum = active_task_sum(paths)
    current_cost = active_cost(paths)
    ratio = current_sum / max(setstate, EPSILON)

    direction = direction_from_target(previous_sum, current_sum, setstate)
    efficiency, improvement, efficiency_value = efficiency_status(
        previous_sum, current_sum, previous_cost, setstate
    )

    active_paths = [path for path in paths if path.active]
    inactive_paths = [path for path in paths if not path.active]

    prune_candidates = [
        path for path in active_paths
        if not path.protected and path.priority != "CORE"
    ]
    prune_candidates.sort(
        key=lambda p: (priority_rank(p.priority), p.value_score(), p.reliability)
    )

    restore_candidates = [
        path for path in inactive_paths
        if not path.protected and path.priority != "CORE"
        and path.contribution > 0.0
    ]
    restore_candidates.sort(
        key=lambda p: (-priority_rank(p.priority), -p.value_score(), -p.reliability)
    )

    prune_candidate = prune_candidates[0] if prune_candidates else None
    restore_candidate = restore_candidates[0] if restore_candidates else None

    projected_ratio_after_prune = ratio
    if prune_candidate:
        projected_sum = current_sum - prune_candidate.contribution
        projected_ratio_after_prune = projected_sum / max(setstate, EPSILON)

    return {
        "current_sum": current_sum,
        "current_cost": current_cost,
        "ratio": ratio,
        "distance": abs(1.0 - ratio),
        "state": classify_state(ratio),
        "direction": direction,
        "efficiency": efficiency,
        "improvement": improvement,
        "efficiency_value": efficiency_value,
        "critical_entries": critical_entries,
        "wasteful_cycles": wasteful_cycles,
        "prune_candidate": prune_candidate,
        "restore_candidate": restore_candidate,
        "projected_ratio_after_prune": projected_ratio_after_prune,
    }

# -----------------------------------------------------------------------------
# RESOLVE AGENT
# Chooses an action from audit evidence.
# -----------------------------------------------------------------------------
def resolve_agent(audit, critical_lockout, failure_detected):
    ratio = audit["ratio"]
    state = audit["state"]

    # Self-healing response has priority after a detected path failure.
    if failure_detected and state in ("WATCH", "SHORTFALL_1_3", "CRITICAL"):
        if audit["restore_candidate"]:
            return {
                "decision_state": "SELF_HEALING",
                "action": "RESTORE_ONE_PATH",
                "reason": "Failure detected; restore the best eligible inactive path.",
                "critical_lockout": state == "CRITICAL",
            }

        return {
            "decision_state": "SELF_HEALING",
            "action": "PROTECT_AND_REDUCE",
            "reason": "Failure detected without a restorable path; protect core capacity.",
            "critical_lockout": state == "CRITICAL",
        }

    if audit["critical_entries"] >= MAX_CRITICAL_ENTRIES:
        return {
            "decision_state": "RESET_REQUIRED",
            "action": "RESEED_PROTECTED_CORE",
            "reason": "Critical-entry limit reached.",
            "critical_lockout": True,
        }

    if critical_lockout and ratio < CRITICAL_EXIT_RATIO:
        return {
            "decision_state": "CRITICAL_LOCKOUT",
            "action": "PROTECT_AND_REDUCE",
            "reason": "Protected recovery remains active below the critical exit ratio.",
            "critical_lockout": True,
        }

    if state == "CRITICAL":
        return {
            "decision_state": "CRITICAL",
            "action": "PROTECT_AND_REDUCE",
            "reason": "Task is below critical floor; protect core and reduce one optional path.",
            "critical_lockout": True,
        }

    if state == "SHORTFALL_1_3":
        return {
            "decision_state": "SHORTFALL_1_3",
            "action": "MONITOR_CANDIDATE",
            "reason": "Shortfall requires cautious observation before removal.",
            "critical_lockout": False,
        }

    if state == "WATCH":
        if audit["direction"] == "CLOSER" and audit["restore_candidate"]:
            return {
                "decision_state": "WATCH",
                "action": "RESTORE_ONE_PATH",
                "reason": "Watch state is improving; restore one eligible path cautiously.",
                "critical_lockout": False,
            }

        return {
            "decision_state": "WATCH",
            "action": "MONITOR_CANDIDATE",
            "reason": "Watch state lacks confirmed recovery.",
            "critical_lockout": False,
        }

    if state == "EFFICIENCY":
        return {
            "decision_state": "EFFICIENCY",
            "action": "SAFE_PRUNE_OR_MONITOR",
            "reason": "Excess activity requires a bounded efficiency correction.",
            "critical_lockout": False,
        }

    if audit["efficiency"] == "WASTEFUL":
        if audit["wasteful_cycles"] >= WASTEFUL_CONFIRMATION_CYCLES:
            return {
                "decision_state": "BALANCE",
                "action": "SAFE_PRUNE_OR_MONITOR",
                "reason": "Repeated wasteful movement supports candidate review.",
                "critical_lockout": False,
            }

        return {
            "decision_state": "BALANCE",
            "action": "HOLD_AND_AUDIT",
            "reason": "One wasteful cycle is insufficient evidence for pruning.",
            "critical_lockout": False,
        }

    return {
        "decision_state": "BALANCE",
        "action": "RETAIN_AND_AUDIT",
        "reason": "System is balanced without confirmed need for intervention.",
        "critical_lockout": False,
    }

# -----------------------------------------------------------------------------
# BOUNDED ACTION AGENT
# Normal actions alter at most one optional path per cycle.
# -----------------------------------------------------------------------------
def bounded_action_agent(paths, audit, decision):
    action = decision["action"]
    changed_paths = []
    result = "NO_PATH_CHANGE"

    if action == "SAFE_PRUNE_OR_MONITOR":
        candidate = audit["prune_candidate"]

        if candidate is None:
            result = "NO_OPTIONAL_PATH_AVAILABLE"

        elif candidate.monitored_cycles < 1:
            candidate.monitored_cycles += 1
            candidate.status = "MONITORED"
            changed_paths.append(candidate.name)
            result = "MONITORED_NOT_PRUNED"

        elif audit["projected_ratio_after_prune"] < BALANCE_FLOOR:
            candidate.monitored_cycles += 1
            candidate.status = "PRUNE_BLOCKED_BY_SAFETY_GUARD"
            changed_paths.append(candidate.name)
            result = "PRUNE_BLOCKED_BY_SAFETY_GUARD"

        else:
            candidate.active = False
            candidate.status = "PRUNED"
            candidate.monitored_cycles = 0
            changed_paths.append(candidate.name)
            result = "PRUNED_SAFELY"

    elif action == "MONITOR_CANDIDATE":
        candidate = audit["prune_candidate"]

        if candidate:
            candidate.monitored_cycles += 1
            candidate.status = "MONITORED"
            changed_paths.append(candidate.name)
            result = "CANDIDATE_MONITORED"
        else:
            result = "NO_OPTIONAL_PATH_TO_MONITOR"

    elif action == "RESTORE_ONE_PATH":
        candidate = audit["restore_candidate"]

        if candidate is None:
            result = "NO_PATH_AVAILABLE_TO_RESTORE"
        else:
            candidate.active = True
            candidate.status = "SELF_HEALED_RESTORED"
            candidate.monitored_cycles = 0
            changed_paths.append(candidate.name)
            result = "PATH_RESTORED_FOR_HEALING"

    elif action == "PROTECT_AND_REDUCE":
        for path in paths:
            if path.protected or path.priority == "CORE":
                if not path.active:
                    path.active = True
                    changed_paths.append(path.name)
                path.status = "CORE_PROTECTED"

        optional = [
            path for path in paths
            if path.active and not path.protected and path.priority != "CORE"
        ]
        optional.sort(key=lambda p: p.value_score())

        if optional:
            path = optional[0]
            path.active = False
            path.status = "PROTECTIVE_PRUNE"
            path.monitored_cycles = 0
            changed_paths.append(path.name)

        result = "CORE_PROTECTED_AND_OPTIONAL_REDUCED"

    elif action == "RESEED_PROTECTED_CORE":
        for path in paths:
            if path.protected or path.priority == "CORE":
                if not path.active:
                    changed_paths.append(path.name)
                path.active = True
                path.status = "SOURCE_RESEEDED"
            else:
                if path.active:
                    changed_paths.append(path.name)
                path.active = False
                path.status = "RESET_PRUNED"
                path.monitored_cycles = 0

        result = "RESEEDED_FROM_PROTECTED_CORE"

    return {
        "result": result,
        "changed_paths": changed_paths,
    }

# -----------------------------------------------------------------------------
# CONTROLLED FAILURE INJECTION
# -----------------------------------------------------------------------------
def inject_failure(paths, cycle):
    if cycle != FAILURE_CYCLE:
        return None

    for path in paths:
        if path.name == FAILURE_PATH_NAME and path.active:
            lost_contribution = path.contribution
            path.active = False
            path.status = "FAILED_OFFLINE"
            return {
                "path": path.name,
                "lost_contribution": lost_contribution,
            }

    return {
        "path": FAILURE_PATH_NAME,
        "lost_contribution": 0.0,
    }

# -----------------------------------------------------------------------------
# DETERMINISTIC ENVIRONMENT
# -----------------------------------------------------------------------------
def update_active_path_contributions(paths, cycle):
    for path in paths:
        if not path.active:
            continue

        if path.protected:
            change = 0.5
        elif path.reliability >= 0.85:
            change = 1.0
        elif path.reliability >= 0.60:
            change = 0.2
        else:
            change = -1.5

        if cycle % 4 == 0 and not path.protected:
            change -= 0.5

        path.contribution = max(0.0, path.contribution + change)

# -----------------------------------------------------------------------------
# INDEPENDENT POST-RUN SELF-AUDIT
# Reads history after execution; it does not select operational actions.
# -----------------------------------------------------------------------------
def independent_self_audit(history, final_paths, setstate):
    checks = []

    protected_paths = [p for p in final_paths if p.protected or p.priority == "CORE"]
    protected_active = all(p.active for p in protected_paths)

    checks.append({
        "rule": "Protected core paths remain active at final state",
        "result": "PASS" if protected_active else "FAIL",
        "evidence": ", ".join(p.name for p in protected_paths if p.active)
                    or "No protected path active",
    })

    ordinary_prune_results = [
        row for row in history
        if row["action"] == "SAFE_PRUNE_OR_MONITOR"
        and row["result"] == "PRUNED_SAFELY"
    ]

    monitor_before_prune = True
    for prune_row in ordinary_prune_results:
        path_name = prune_row["changed_paths"][0] if prune_row["changed_paths"] else None
        prior_monitor = any(
            earlier["cycle"] < prune_row["cycle"]
            and path_name in earlier["changed_paths"]
            and earlier["result"] in (
                "MONITORED_NOT_PRUNED",
                "CANDIDATE_MONITORED",
            )
            for earlier in history
        )
        if not prior_monitor:
            monitor_before_prune = False

    checks.append({
        "rule": "Ordinary pruning follows earlier monitoring",
        "result": "PASS" if monitor_before_prune else "FAIL",
        "evidence": (
            f"{len(ordinary_prune_results)} safe-prune event(s) checked"
        ),
    })

    unsafe_prunes = [
        row for row in history
        if row["result"] == "PRUNED_SAFELY"
        and row["projected_ratio_after_prune"] < BALANCE_FLOOR
    ]

    checks.append({
        "rule": "No ordinary prune violates balance safety floor",
        "result": "PASS" if not unsafe_prunes else "FAIL",
        "evidence": (
            "No unsafe safe-prune events"
            if not unsafe_prunes
            else f"{len(unsafe_prunes)} unsafe prune event(s)"
        ),
    })

    failure_rows = [row for row in history if row["failure_event"] is not None]
    healing_rows = [row for row in history if row["result"] == "PATH_RESTORED_FOR_HEALING"]

    if not failure_rows:
        healing_result = "WARNING"
        healing_evidence = "No failure injection recorded"
    elif not healing_rows:
        healing_result = "WARNING"
        healing_evidence = "Failure occurred but no eligible restoration was performed"
    else:
        failure_cycle = failure_rows[0]["cycle"]
        failure_ratio = failure_rows[0]["post_failure_ratio"]

        later_rows = [
            row for row in history
            if failure_cycle < row["cycle"] <= failure_cycle + HEALING_WINDOW
        ]

        best_ratio = max(
            [row["next_ratio"] for row in later_rows] + [failure_ratio]
        )

        if best_ratio > failure_ratio:
            healing_result = "PASS"
            healing_evidence = (
                f"Failure ratio {failure_ratio:.3f}; "
                f"best ratio within healing window {best_ratio:.3f}"
            )
        else:
            healing_result = "WARNING"
            healing_evidence = (
                f"Failure ratio {failure_ratio:.3f}; "
                f"no improvement within healing window"
            )

    checks.append({
        "rule": "Controlled failure triggers measurable recovery",
        "result": healing_result,
        "evidence": healing_evidence,
    })

    bounded_changes = True
    violations = []

    for row in history:
        normal_action = row["action"] not in (
            "PROTECT_AND_REDUCE",
            "RESEED_PROTECTED_CORE",
        )
        if normal_action and len(row["changed_paths"]) > 1:
            bounded_changes = False
            violations.append(row["cycle"])

    checks.append({
        "rule": "Normal cycle changes at most one optional path",
        "result": "PASS" if bounded_changes else "FAIL",
        "evidence": (
            "No normal-cycle action exceeded one path"
            if bounded_changes
            else f"Violation cycle(s): {violations}"
        ),
    })

    pass_count = sum(check["result"] == "PASS" for check in checks)
    warning_count = sum(check["result"] == "WARNING" for check in checks)
    fail_count = sum(check["result"] == "FAIL" for check in checks)

    return checks, pass_count, warning_count, fail_count

# -----------------------------------------------------------------------------
# DISPLAY HELPERS
# -----------------------------------------------------------------------------
def path_name(path):
    return path.name if path else "None"

def print_paths(paths):
    print(
        f"{'Path':<16}"
        f"{'Contribution':<15}"
        f"{'Cost':<9}"
        f"{'Reliability':<12}"
        f"{'Priority':<10}"
        f"{'Protected':<11}"
        f"{'Active':<8}"
        f"{'Status'}"
    )
    print("-" * 110)

    for path in paths:
        print(
            f"{path.name:<16}"
            f"{path.contribution:<15.2f}"
            f"{path.cost:<9.2f}"
            f"{path.reliability:<12.2f}"
            f"{path.priority:<10}"
            f"{str(path.protected):<11}"
            f"{str(path.active):<8}"
            f"{path.status}"
        )

# -----------------------------------------------------------------------------
# INITIAL PATH CONFIGURATION
# Reliable_Path fails at cycle 6.
# Medium_Path becomes the best eligible recovery candidate.
# -----------------------------------------------------------------------------
INITIAL_PATHS = [
    TaskPath("Core_Signal",   32.0, 2.0, 0.98, "CORE",   True),
    TaskPath("Core_Memory",   24.0, 2.5, 0.92, "CORE",   True),
    TaskPath("Reliable_Path", 18.0, 2.0, 0.88, "HIGH",   False),
    TaskPath("Medium_Path",   14.0, 4.0, 0.62, "NORMAL", False),
    TaskPath("Weak_Path",     10.0, 6.0, 0.32, "LOW",    False),
]

# -----------------------------------------------------------------------------
# MAIN EXECUTION
# -----------------------------------------------------------------------------
paths = deepcopy(INITIAL_PATHS)

previous_sum = active_task_sum(paths)
previous_cost = max(active_cost(paths), 1.0)

critical_lockout = False
critical_entries = 0
wasteful_cycles = 0
failure_detected = False
history = []

print("\n" + "=" * 110)
print("THREE-AGENT PROCESS DESIGN ENGINE v0.5.1")
print("AUDIT + SELF-HEALING TEST HARNESS")
print("=" * 110)
print(f"SetState: {SETSTATE_TASK_SUM:.2f}")
print(f"Balance safety floor: {BALANCE_FLOOR:.2f}")
print(f"Failure injection: cycle {FAILURE_CYCLE}, path {FAILURE_PATH_NAME}")
print(f"Healing evaluation window: {HEALING_WINDOW} cycles")
print("\nINITIAL PATH CONFIGURATION")
print_paths(paths)

for cycle in range(1, MAX_CYCLES + 1):
    # Failure happens before measurement and audit in the chosen cycle.
    failure_event = inject_failure(paths, cycle)

    if failure_event and failure_event["lost_contribution"] > 0:
        failure_detected = True

    current_sum_after_failure = active_task_sum(paths)
    post_failure_ratio = current_sum_after_failure / SETSTATE_TASK_SUM

    # Operational audit.
    audit = audit_agent(
        paths=paths,
        setstate=SETSTATE_TASK_SUM,
        previous_sum=previous_sum,
        previous_cost=previous_cost,
        critical_entries=critical_entries,
        wasteful_cycles=wasteful_cycles,
    )

    if audit["efficiency"] == "WASTEFUL":
        wasteful_cycles += 1
    else:
        wasteful_cycles = 0

    if audit["state"] == "CRITICAL":
        critical_entries += 1

    audit["wasteful_cycles"] = wasteful_cycles
    audit["critical_entries"] = critical_entries

    # Resolve a bounded response.
    decision = resolve_agent(
        audit=audit,
        critical_lockout=critical_lockout,
        failure_detected=failure_detected,
    )
    critical_lockout = decision["critical_lockout"]

    # Execute bounded action.
    action_result = bounded_action_agent(paths, audit, decision)

    # A successful restoration satisfies the immediate self-healing response.
    if action_result["result"] == "PATH_RESTORED_FOR_HEALING":
        failure_detected = False

    # Environment updates active path contributions for next cycle.
    update_active_path_contributions(paths, cycle)
    next_sum = active_task_sum(paths)
    next_ratio = next_sum / SETSTATE_TASK_SUM

    row = {
        "cycle": cycle,
        "current_sum": audit["current_sum"],
        "ratio": audit["ratio"],
        "state": audit["state"],
        "direction": audit["direction"],
        "efficiency": audit["efficiency"],
        "action": decision["action"],
        "decision_state": decision["decision_state"],
        "result": action_result["result"],
        "changed_paths": action_result["changed_paths"],
        "prune_candidate": path_name(audit["prune_candidate"]),
        "projected_ratio_after_prune": audit["projected_ratio_after_prune"],
        "failure_event": failure_event,
        "post_failure_ratio": post_failure_ratio,
        "next_sum": next_sum,
        "next_ratio": next_ratio,
    }
    history.append(row)

    print("\n" + "-" * 110)
    print(f"CYCLE {cycle}")
    print("-" * 110)

    if failure_event and failure_event["lost_contribution"] > 0:
        print(
            f"FAILURE  | {failure_event['path']} forced offline; "
            f"lost contribution: {failure_event['lost_contribution']:.2f} | "
            f"post-failure ratio: {post_failure_ratio:.3f}"
        )

    print(
        f"MEASURE  | Sum: {audit['current_sum']:.2f} | "
        f"Ratio: {audit['ratio']:.3f} | "
        f"State: {audit['state']} | "
        f"Direction: {audit['direction']} | "
        f"Efficiency: {audit['efficiency']}"
    )
    print(
        f"AUDIT    | Prune candidate: {path_name(audit['prune_candidate'])} | "
        f"Restore candidate: {path_name(audit['restore_candidate'])} | "
        f"Projected post-prune ratio: {audit['projected_ratio_after_prune']:.3f}"
    )
    print(
        f"RESOLVE  | {decision['decision_state']} | "
        f"Action: {decision['action']}"
    )
    print(f"REASON   | {decision['reason']}")
    print(f"ACTION   | {action_result['result']}")
    print(
        "CHANGED  | " +
        (", ".join(action_result["changed_paths"])
         if action_result["changed_paths"] else "None")
    )
    print(f"NEXT     | Task sum: {next_sum:.2f} | Ratio: {next_ratio:.3f}")

    previous_sum = audit["current_sum"]
    previous_cost = max(audit["current_cost"], 1.0)

# -----------------------------------------------------------------------------
# INDEPENDENT SELF-AUDIT REPORT
# -----------------------------------------------------------------------------
checks, pass_count, warning_count, fail_count = independent_self_audit(
    history=history,
    final_paths=paths,
    setstate=SETSTATE_TASK_SUM,
)

final_sum = active_task_sum(paths)
final_ratio = final_sum / SETSTATE_TASK_SUM
final_state = classify_state(final_ratio)

print("\n" + "=" * 110)
print("FINAL PATH CONFIGURATION")
print("=" * 110)
print_paths(paths)

print("\n" + "=" * 110)
print("INDEPENDENT SELF-AUDIT REPORT")
print("=" * 110)
print(f"{'Rule':<58}{'Result':<10}Evidence")
print("-" * 110)

for check in checks:
    print(
        f"{check['rule']:<58}"
        f"{check['result']:<10}"
        f"{check['evidence']}"
    )

print("-" * 110)
print(
    f"Audit totals: PASS = {pass_count} | "
    f"WARNING = {warning_count} | FAIL = {fail_count}"
)

print("\nFINAL ENGINE STATE")
print(f"Final active task sum: {final_sum:.2f}")
print(f"Final ratio: {final_ratio:.3f}")
print(f"Final state: {final_state}")

if BALANCE_FLOOR <= final_ratio < EFFICIENCY_CEILING:
    verdict = "BALANCE RANGE REACHED"
elif WATCH_FLOOR <= final_ratio < BALANCE_FLOOR:
    verdict = "WATCH / PARTIAL RECOVERY"
elif final_ratio < CRITICAL_FLOOR:
    verdict = "CRITICAL SHORTFALL REMAINS"
elif final_ratio < WATCH_FLOOR:
    verdict = "ONE-THIRD SHORTFALL REMAINS"
else:
    verdict = "EFFICIENCY CORRECTION STILL NEEDED"

print(f"FINAL VERDICT: {verdict}")
print("=" * 110)
print("v0.5.1 test: the operational engine acts; the post-run audit evaluates.")
print("Self-healing means bounded recovery from the injected path failure.")
print("=" * 110)
# Out:
# ==============================================================================================================
# THREE-AGENT PROCESS DESIGN ENGINE v0.5.1
# AUDIT + SELF-HEALING TEST HARNESS
# ==============================================================================================================
# SetState: 100.00
# Balance safety floor: 0.90
# Failure injection: cycle 3, path Reliable_Path
# Healing evaluation window: 2 cycles
#
# INITIAL PATH CONFIGURATION
# Path            Contribution   Cost     Reliability Priority  Protected  Active  Status
# --------------------------------------------------------------------------------------------------------------
# Core_Signal     32.00          2.00     0.98        CORE      True       True    ACTIVE
# Core_Memory     24.00          2.50     0.92        CORE      True       True    ACTIVE
# Reliable_Path   18.00          2.00     0.88        HIGH      False      True    ACTIVE
# Medium_Path     14.00          4.00     0.62        NORMAL    False      True    ACTIVE
# Weak_Path       10.00          6.00     0.32        LOW       False      True    ACTIVE
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 1
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 98.00 | Ratio: 0.980 | State: BALANCE | Direction: NO_CHANGE | Efficiency: STALLED
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 0.880
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 98.70 | Ratio: 0.987
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 2
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 98.70 | Ratio: 0.987 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 0.902
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 99.40 | Ratio: 0.994
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 3
# --------------------------------------------------------------------------------------------------------------
# FAILURE  | Reliable_Path forced offline; lost contribution: 20.00 | post-failure ratio: 0.794
# MEASURE  | Sum: 79.40 | Ratio: 0.794 | State: SHORTFALL_1_3 | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: Reliable_Path | Projected post-prune ratio: 0.724
# RESOLVE  | SELF_HEALING | Action: RESTORE_ONE_PATH
# REASON   | Failure detected; restore the best eligible inactive path.
# ACTION   | PATH_RESTORED_FOR_HEALING
# CHANGED  | Reliable_Path
# NEXT     | Task sum: 100.10 | Ratio: 1.001
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 4
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 100.10 | Ratio: 1.001 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 0.946
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 99.30 | Ratio: 0.993
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 5
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 99.30 | Ratio: 0.993 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 0.958
# RESOLVE  | BALANCE | Action: HOLD_AND_AUDIT
# REASON   | One wasteful cycle is insufficient evidence for pruning.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 100.00 | Ratio: 1.000
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 6
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 100.00 | Ratio: 1.000 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 0.980
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 100.70 | Ratio: 1.007
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 7
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 100.70 | Ratio: 1.007 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 1.002
# RESOLVE  | BALANCE | Action: HOLD_AND_AUDIT
# REASON   | One wasteful cycle is insufficient evidence for pruning.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 102.40 | Ratio: 1.024
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 8
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 102.40 | Ratio: 1.024 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 1.024
# RESOLVE  | BALANCE | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Repeated wasteful movement supports candidate review.
# ACTION   | MONITORED_NOT_PRUNED
# CHANGED  | Weak_Path
# NEXT     | Task sum: 103.60 | Ratio: 1.036
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 9
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 103.60 | Ratio: 1.036 | State: BALANCE | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Weak_Path | Restore candidate: None | Projected post-prune ratio: 1.036
# RESOLVE  | BALANCE | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Repeated wasteful movement supports candidate review.
# ACTION   | PRUNED_SAFELY
# CHANGED  | Weak_Path
# NEXT     | Task sum: 105.80 | Ratio: 1.058
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 10
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 105.80 | Ratio: 1.058 | State: EFFICIENCY | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Medium_Path | Restore candidate: None | Projected post-prune ratio: 0.910
# RESOLVE  | EFFICIENCY | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Excess activity requires a bounded efficiency correction.
# ACTION   | MONITORED_NOT_PRUNED
# CHANGED  | Medium_Path
# NEXT     | Task sum: 108.00 | Ratio: 1.080
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 11
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 108.00 | Ratio: 1.080 | State: EFFICIENCY | Direction: FARTHER | Efficiency: WASTEFUL
# AUDIT    | Prune candidate: Medium_Path | Restore candidate: None | Projected post-prune ratio: 0.930
# RESOLVE  | EFFICIENCY | Action: SAFE_PRUNE_OR_MONITOR
# REASON   | Excess activity requires a bounded efficiency correction.
# ACTION   | PRUNED_SAFELY
# CHANGED  | Medium_Path
# NEXT     | Task sum: 95.00 | Ratio: 0.950
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 12
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 95.00 | Ratio: 0.950 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Prune candidate: Reliable_Path | Restore candidate: Medium_Path | Projected post-prune ratio: 0.670
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 96.50 | Ratio: 0.965
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 13
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 96.50 | Ratio: 0.965 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Prune candidate: Reliable_Path | Restore candidate: Medium_Path | Projected post-prune ratio: 0.680
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 98.50 | Ratio: 0.985
#
# --------------------------------------------------------------------------------------------------------------
# CYCLE 14
# --------------------------------------------------------------------------------------------------------------
# MEASURE  | Sum: 98.50 | Ratio: 0.985 | State: BALANCE | Direction: CLOSER | Efficiency: PRODUCTIVE
# AUDIT    | Prune candidate: Reliable_Path | Restore candidate: Medium_Path | Projected post-prune ratio: 0.690
# RESOLVE  | BALANCE | Action: RETAIN_AND_AUDIT
# REASON   | System is balanced without confirmed need for intervention.
# ACTION   | NO_PATH_CHANGE
# CHANGED  | None
# NEXT     | Task sum: 100.50 | Ratio: 1.005
#
# ==============================================================================================================
# FINAL PATH CONFIGURATION
# ==============================================================================================================
# Path            Contribution   Cost     Reliability Priority  Protected  Active  Status
# --------------------------------------------------------------------------------------------------------------
# Core_Signal     39.00          2.00     0.98        CORE      True       True    ACTIVE
# Core_Memory     31.00          2.50     0.92        CORE      True       True    ACTIVE
# Reliable_Path   30.50          2.00     0.88        HIGH      False      True    SELF_HEALED_RESTORED
# Medium_Path     15.00          4.00     0.62        NORMAL    False      False   PRUNED
# Weak_Path       0.00           6.00     0.32        LOW       False      False   PRUNED
#
# ==============================================================================================================
# INDEPENDENT SELF-AUDIT REPORT
# ==============================================================================================================
# Rule                                                      Result    Evidence
# --------------------------------------------------------------------------------------------------------------
# Protected core paths remain active at final state         PASS      Core_Signal, Core_Memory
# Ordinary pruning follows earlier monitoring               PASS      2 safe-prune event(s) checked
# No ordinary prune violates balance safety floor           PASS      No unsafe safe-prune events
# Controlled failure triggers measurable recovery           PASS      Failure ratio 0.794; best ratio within healing window 1.000
# Normal cycle changes at most one optional path            PASS      No normal-cycle action exceeded one path
# --------------------------------------------------------------------------------------------------------------
# Audit totals: PASS = 5 | WARNING = 0 | FAIL = 0
#
# FINAL ENGINE STATE
# Final active task sum: 100.50
# Final ratio: 1.005
# Final state: BALANCE
# FINAL VERDICT: BALANCE RANGE REACHED
# ==============================================================================================================
# v0.5.1 test: the operational engine acts; the post-run audit evaluates.
# Self-healing means bounded recovery from the injected path failure.
# ==============================================================================================================

# %% [markdown]
# ### Self-Healing Recovery Logic Explanation
#
# The `independent_self_audit` function contains a crucial section to assess if the system successfully recovered after a simulated failure. This is done by looking at the historical data generated during the engine's execution.
#
# Here's how this part of the audit works:

# %%
def explain_self_healing_audit_logic():
    print("1. **Identify Failure and Healing Events:**")
    print("   - It first filters the `history` to find when a `failure_event` occurred (`failure_rows`) and when a path was restored for healing (`healing_rows`).")
    print("   - If no failure was injected (`failure_rows` is empty), it reports a 'WARNING' because the healing mechanism couldn't be tested.")
    print("   - If a failure occurred but no path was restored (`healing_rows` is empty), it also issues a 'WARNING'.")
    print("\n2. **Determine Healing Window:**")
    print("   - If a failure was detected, it captures the `failure_cycle` and the `post_failure_ratio` (the system's performance ratio immediately after the failure).")
    print("   - It then looks at subsequent cycles within a defined `HEALING_WINDOW` (e.g., 4 cycles after the failure) to find the system's `best_ratio` during that period.")
    print("\n3. **Evaluate Recovery:**")
    print("   - It compares the `best_ratio` achieved within the healing window to the `post_failure_ratio`.")
    print("   - **PASS:** If the `best_ratio` is greater than the `post_failure_ratio`, it means the system improved its performance after the failure, indicating a successful self-healing attempt. This implies the actions taken by the Resolve and Bounded Action agents (like restoring a path) were effective.")
    print("   - **WARNING:** If the system did not improve (i.e., `best_ratio` is not greater than `post_failure_ratio`), it signals a 'WARNING'. This suggests that while a failure occurred and possibly actions were taken, they didn't lead to a measurable recovery within the specified healing timeframe.")
    print("\nThis independent check is crucial because it validates the effectiveness of the self-healing mechanisms without interfering with the operational logic of the three agents. It confirms whether the system can detect a problem and take corrective, bounded actions to bring itself back towards a healthy state.")

explain_self_healing_audit_logic()
# Out:
# 1. **Identify Failure and Healing Events:**
#    - It first filters the `history` to find when a `failure_event` occurred (`failure_rows`) and when a path was restored for healing (`healing_rows`).
#    - If no failure was injected (`failure_rows` is empty), it reports a 'WARNING' because the healing mechanism couldn't be tested.
#    - If a failure occurred but no path was restored (`healing_rows` is empty), it also issues a 'WARNING'.
#
# 2. **Determine Healing Window:**
#    - If a failure was detected, it captures the `failure_cycle` and the `post_failure_ratio` (the system's performance ratio immediately after the failure).
#    - It then looks at subsequent cycles within a defined `HEALING_WINDOW` (e.g., 4 cycles after the failure) to find the system's `best_ratio` during that period.
#
# 3. **Evaluate Recovery:**
#    - It compares the `best_ratio` achieved within the healing window to the `post_failure_ratio`.
#    - **PASS:** If the `best_ratio` is greater than the `post_failure_ratio`, it means the system improved its performance after the failure, indicating a successful self-healing attempt. This implies the actions taken by the Resolve and Bounded Action agents (like restoring a path) were effective.
#    - **WARNING:** If the system did not improve (i.e., `best_ratio` is not greater than `post_failure_ratio`), it signals a 'WARNING'. This suggests that while a failure occurred and possibly actions were taken, they didn't lead to a measurable recovery within the specified healing timeframe.
#
# This independent check is crucial because it validates the effectiveness of the self-healing mechanisms without interfering with the operational logic of the three agents. It confirms whether the system can detect a problem and take corrective, bounded actions to bring itself back towards a healthy state.
